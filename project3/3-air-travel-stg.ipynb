# %% [markdown]
# ### Create the staging layer for the Air Travel warehouse

# %% [markdown]
# ### Declare variables used throughout

# %%
project_id = "cs329e-sp2025"
dataset = "air_travel_stg"
region = "us-central1"
model_name = "gemini-2.0-flash-001"  # latest Gemini model as of 02/07/25

# %% [markdown]
# ### Create staging dataset

# %%
from google.cloud import bigquery

bq_client = bigquery.Client()

dataset_id = bigquery.Dataset(f"{project_id}.{dataset}")
dataset_id.location = region
resp = bq_client.create_dataset(dataset_id, exists_ok=True)
print("Created dataset {}.{}".format(bq_client.project, resp.dataset_id))
# Out:
# Created dataset cs329e-sp2025.air_travel_stg

# %% [markdown]
# ### `aircrafts` table

# %% [markdown]
# ##### Replace `'\\N'` with null

# %%
# %%bigquery
# select aircraft_name, iata_code,
# case icao_code when '\\N' then null else icao_code end as icao_code,
#   _data_source, _load_time
# from air_travel_raw.aircrafts;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                       aircraft_name iata_code icao_code  \
# 0                                       Airbus A330       330      None
# 1                                       Airbus A340       340      None
# 2                                       Airbus A350       350      None
# 3                                       Airbus A380       380      None
# 4                                           BAe 146       146      None
# ..                                              ...       ...       ...
# 241                                  Tupolev Tu-204       T20      T204
# 242  Pilatus Britten-Norman BN-2A Mk III Trislander       BNT      TRIS
# 243                                 Yakovlev Yak-40       YK4      YK40
# 244                                 Yakovlev Yak-42       YK2      YK42
# 245                                      NAMC YS-11       YS1      YS11
#
#     _data_source                       _load_time
# 0    openflights 2025-01-24 18:55:21.985992+00:00
# 1    openflights 2025-01-24 18:55:21.985992+00:00
# 2    openflights 2025-01-24 18:55:21.985992+00:00
# 3    openflights 2025-01-24 18:55:21.985992+00:00
# 4    openflights 2025-01-24 18:55:21.985992+00:00
# ..           ...                              ...
# 241  openflights 2025-01-24 18:55:21.985992+00:00
# 242  openflights 2025-01-24 18:55:21.985992+00:00
# 243  openflights 2025-01-24 18:55:21.985992+00:00
# 244  openflights 2025-01-24 18:55:21.985992+00:00
# 245  openflights 2025-01-24 18:55:21.985992+00:00
#
# [246 rows x 5 columns]

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.aircrafts as
#   select aircraft_name as name,
#   case iata_code when '\\N' then null else iata_code end as iata,
#   case icao_code when '\\N' then null else icao_code end as icao,
#   _data_source,
#   _load_time
#   from air_travel_raw.aircrafts;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airlines` table

# %% [markdown]
# ##### Replace `'\\N'` with null

# %%
# %%bigquery
# select airline_id as id,
# name,
# case alias when '\\N' then null else alias end as alias,
# iata, icao, callsign,
# case country when '\\N' then null else country end as country,
# active, _data_source, _load_time
# from air_travel_raw.airlines;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          id                            name alias iata icao          callsign  \
# 0       415           Aerojet de Costa Rica  None       ARJ              S.A.
# 1      1509               Bellview Airlines  None       BVU      Sierra Leone
# 2      1516                      BAX Global  None   8W
# 3      2080         Electronic Data Systems  None        1Y
# 4      2636  Gulf African Airlines - Gambia  None       GUF      GULF AFRICAN
# ...     ...                             ...   ...  ...  ...               ...
# 6157   2773              Hong Kong Airlines  None   HX  CRK          BAUHINIA
# 6158   2774       Hong Kong Express Airways  None   UO  HKE  HONGKONG SHUTTLE
# 6159   3233                    Lao Airlines  None   QV  LAO               LAO
# 6160  11724                         SVG Air             SVG        Grenadines
# 6161    998                       Air Koryo  None   JS  KOR         AIR KORYO
#
#                                     country  active _data_source  \
# 0                                             False  openflights
# 1                                             False  openflights
# 2                                             False  openflights
# 3                                             False  openflights
# 4                                             False  openflights
# ...                                     ...     ...          ...
# 6157                 Hong Kong SAR of China    True  openflights
# 6158                 Hong Kong SAR of China    True  openflights
# 6159        Lao Peoples Democratic Republic    True  openflights
# 6160       Saint Vincent and the Grenadines    True  openflights
# 6161  Democratic People's Republic of Korea    True  openflights
#
#                            _load_time
# 0    2025-01-24 18:52:44.140187+00:00
# 1    2025-01-24 18:52:44.140187+00:00
# 2    2025-01-24 18:52:44.140187+00:00
# 3    2025-01-24 18:52:44.140187+00:00
# 4    2025-01-24 18:52:44.140187+00:00
# ...                               ...
# 6157 2025-01-24 18:52:44.140187+00:00
# 6158 2025-01-24 18:52:44.140187+00:00
# 6159 2025-01-24 18:52:44.140187+00:00
# 6160 2025-01-24 18:52:44.140187+00:00
# 6161 2025-01-24 18:52:44.140187+00:00
#
# [6162 rows x 10 columns]

# %% [markdown]
# ##### Look for empty strings

# %%
# %%bigquery
# select count(*) as empty_alias
# from air_travel_raw.airlines
# where alias = '';
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_alias
# 0          505

# %%
# %%bigquery
# select count(*) as empty_country
# from air_travel_raw.airlines
# where country = '';
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_country
# 0             15

# %% [markdown]
# ##### Putting it all together

# %%
# %%bigquery
# select airline_id as id,
# name,
# case alias
#   when '\\N' then null
#   when '' then null
#   else alias
#   end as alias,
# case iata
#   when '' then null
#   else iata
#   end as iata,
# case icao
#   when '' then null
#   else icao
#   end as icao,
# case callsign
#   when '' then null
#   else callsign
#   end as callsign,
# case country
#   when '\\N' then null
#   when '' then null
#   else country end as country,
# active, _data_source, _load_time
# from air_travel_raw.airlines;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          id                            name alias  iata  icao  \
# 0       415           Aerojet de Costa Rica  None  None   ARJ
# 1      1509               Bellview Airlines  None  None   BVU
# 2      1516                      BAX Global  None    8W  None
# 3      2080         Electronic Data Systems  None  None    1Y
# 4      2636  Gulf African Airlines - Gambia  None  None   GUF
# ...     ...                             ...   ...   ...   ...
# 6157   2773              Hong Kong Airlines  None    HX   CRK
# 6158   2774       Hong Kong Express Airways  None    UO   HKE
# 6159   3233                    Lao Airlines  None    QV   LAO
# 6160  11724                         SVG Air  None  None   SVG
# 6161    998                       Air Koryo  None    JS   KOR
#
#               callsign                                country  active  \
# 0                 S.A.                                   None   False
# 1         Sierra Leone                                   None   False
# 2                 None                                   None   False
# 3                 None                                   None   False
# 4         GULF AFRICAN                                   None   False
# ...                ...                                    ...     ...
# 6157          BAUHINIA                 Hong Kong SAR of China    True
# 6158  HONGKONG SHUTTLE                 Hong Kong SAR of China    True
# 6159               LAO        Lao Peoples Democratic Republic    True
# 6160        Grenadines       Saint Vincent and the Grenadines    True
# 6161         AIR KORYO  Democratic People's Republic of Korea    True
#
#      _data_source                       _load_time
# 0     openflights 2025-01-24 18:52:44.140187+00:00
# 1     openflights 2025-01-24 18:52:44.140187+00:00
# 2     openflights 2025-01-24 18:52:44.140187+00:00
# 3     openflights 2025-01-24 18:52:44.140187+00:00
# 4     openflights 2025-01-24 18:52:44.140187+00:00
# ...           ...                              ...
# 6157  openflights 2025-01-24 18:52:44.140187+00:00
# 6158  openflights 2025-01-24 18:52:44.140187+00:00
# 6159  openflights 2025-01-24 18:52:44.140187+00:00
# 6160  openflights 2025-01-24 18:52:44.140187+00:00
# 6161  openflights 2025-01-24 18:52:44.140187+00:00
#
# [6162 rows x 10 columns]

# %% [markdown]
# ##### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.airlines as
#   select airline_id as id,
#   name,
#   case alias
#     when '\\N' then null
#     when '' then null
#     else alias
#     end as alias,
#   case iata
#     when '' then null
#     else iata
#     end as iata,
#   case icao
#     when '' then null
#     else icao
#     end as icao,
#   case callsign
#     when '' then null
#     else callsign
#     end as callsign,
#   case country
#     when '\\N' then null
#     when '' then null
#     else country end as country,
#   active, _data_source, _load_time
#   from air_travel_raw.airlines;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airport_businesses` table

# %% [markdown]
# #### Profile category values

# %%
# %%bigquery
# select distinct category
# from air_travel_raw.airport_businesses
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                category
# 0                   ATM
# 1        Administration
# 2           Air Service
# 3    Air Transportation
# 4               Airline
# ..                  ...
# 184          restaurant
# 185            security
# 186    shipping company
# 187            shopping
# 188      transportation
#
# [189 rows x 1 columns]

# %%
# %%bigquery
# select category, count(*) as airline_categories
# from air_travel_raw.airport_businesses
# where category like '%Airline%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                   category  airline_categories
# 0                  Airline                 108
# 1   Airline Club & Lounges                   3
# 2           Airline Office                   2
# 3         Airline Services                   1
# 4  Airline Ticket Counters                   1
# 5        Airline Ticketing                   3
# 6                 Airlines                  29

# %%
# %%bigquery
# select category, count(*) as airport_categories
# from air_travel_raw.airport_businesses
# where category like '%Airport%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            category  airport_categories
# 0  Airport Facility                   1
# 1  Airport Security                   2
# 2   Airport Service                  40
# 3  Airport Services                 108

# %%
# %%bigquery
# select category, count(*) as food_categories
# from air_travel_raw.airport_businesses
# where category like '%Food%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        category  food_categories
# 0     Fast Food               13
# 1          Food                2
# 2  Food & Drink                4
# 3    Food Court                2
# 4    Food/Drink                3

# %%
# %%bigquery
# select category, count(*) as news_categories
# from air_travel_raw.airport_businesses
# where category like '%News%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                 category  news_categories
# 0                   News                2
# 1           News & Media                5
# 2             News Kiosk                1
# 3             News Stand                2
# 4              Newsagent                1
# 5              Newsstand               39
# 6  Newsstand/Coffee Shop                1

# %%
# %%bigquery
# select category, count(*) as shop_categories
# from air_travel_raw.airport_businesses
# where category like 'Shop%'
# group by category
# order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    category  shop_categories
# 0      Shop                2
# 1  Shopping              160

# %% [markdown]
# #### Standardize the categories using LLM

# %%
import vertexai
from vertexai.generative_models import GenerativeModel, Part

prompt = """Look for categories that have similar meanings and have differences in spelling and naming.
Replace the similar categories with a standard category.
For example, some records have a category of 'Airline Ticket Counters' and others
have a category of 'Airline Ticketing' and they both mean similar things.
Map 'Airline Ticket Counters' to 'Airline Ticketing'.
Return the entire list of original categories along with their new categories.
Format the results as json with the schema: current_category:string, new_category:string.

Below is the list of current_categories:
Airline
Airline Club & Lounges
Airline Office
Airline Services
Airline Ticket Counters
Airline Ticketing
Airlines
"""

vertexai.init(project=project_id, location=region)
model = GenerativeModel(model_name)
resp = model.generate_content([prompt])
resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
print(resp_text)
# Out:
# [    {        "current_category": "Airline",        "new_category": "Airline"    },    {        "current_category": "Airline Club & Lounges",        "new_category": "Airline Club & Lounges"    },     {        "current_category": "Airline Office",        "new_category": "Airline Office"    },    {        "current_category": "Airline Services",        "new_category": "Airline Services"    },    {        "current_category": "Airline Ticket Counters",        "new_category": "Airline Ticketing"    },    {        "current_category": "Airline Ticketing",        "new_category": "Airline Ticketing"    },    {        "current_category":"Airlines",        "new_category":"Airline"    }]

# %% [markdown]
# #### Refine the prompt and make it more dynamic

# %%
import json
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import bigquery

prompt = """Go through the list of categories and look for categories that have similar meanings and have differences in spelling and naming.
For example, 'Airline Ticket Counters' and 'Airline Ticketing' have similar meanings and 'Mother Room and 'Mother's Room' have similar meanings.
Suggest a standard category, mapping the current one to the new one.
Return the list of original categories along with their new categories.
Format the results as a json object with the schema: current_category:string, new_category:string.
Do not include any unchanged categories with your answer.
Do not include an explanation with your answer.
"""
category_sql = """select distinct category from air_travel_raw.airport_businesses
where category like 'R%' order by category limit 30"""

airport_businesses_sql = """select airport_code, terminal, business, category, location
from air_travel_raw.airport_businesses where category like 'R%'
and category != 'Restaurant'
order by category limit 30"""

bq_client = bigquery.Client()
rows = bq_client.query_and_wait(category_sql)

category_list = []
for row in rows:
    category_list.append(row["category"])
category_str = '\n'.join(category_list)
print("category_str:", category_str)

vertexai.init(project=project_id, location=region)
model = GenerativeModel(model_name)
resp = model.generate_content([category_str, prompt])
resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
print(resp_text)
categories = json.loads(resp_text)
print("categories:", categories)

# filter out any unchanged categories
replacements = {}
for old, new in categories:
    if old == new:
        continue
    else:
        replacements[old] = new
print("replacements:", replacements)

df = bq_client.query_and_wait(airport_businesses_sql).to_dataframe()
print("orig df:", df)

df["category"] = df["category"].map(replacements).fillna(df["category"])
print("new df:", df)
# Out:
# category_str: Rental
# Restaurant
# Restroom
# Restrooms
# Retail
# [    {        "current_category": "Restroom",        "new_category": "Restrooms"    }]
# categories: [{'current_category': 'Restroom', 'new_category': 'Restrooms'}]
# replacements: {'current_category': 'new_category'}
# orig df:    airport_code terminal                 business   category  \
# 0           syr        1  Automated Rental Lounge     Rental
# 1           abq        1             Nursing Room   Restroom
# 2           pgd        1            Mother's Room  Restrooms
# 3           blv        1         Family Restrooms  Restrooms
# 4           atw        1              Mother Room  Restrooms
# 5           atw        1              Mother Room  Restrooms
# 6           gtr        1         Vending machines     Retail
# 7           chs        1               Amazon One     Retail
# 8           fsd        1                Gift Shop     Retail
# 9           fsd        1                Gift Shop     Retail
# 10          lax        3           Hudson Nonstop     Retail
# 11          gtr        1         Vending machines     Retail
# 12          gtr        1         Vending machines     Retail
# 13          abq        1               Misc Shops     Retail
#
#                            location
# 0   Terminal 1 Level 1 near Gate 15
# 1                       Third Floor
# 2                            Gate 2
# 3              Level 2 near Gates B
# 4                       Near Gate 6
# 5                       Near Gate 2
# 6                     Gates B3 & B4
# 7                      Near gate A1
# 8                      Near Gate 15
# 9                       Near Gate 5
# 10                         Gate 37B
# 11                          Gate B2
# 12                          Gate B1
# 13                          Gate A2
# new df:    airport_code terminal                 business   category  \
# 0           syr        1  Automated Rental Lounge     Rental
# 1           abq        1             Nursing Room   Restroom
# 2           pgd        1            Mother's Room  Restrooms
# 3           blv        1         Family Restrooms  Restrooms
# 4           atw        1              Mother Room  Restrooms
# 5           atw        1              Mother Room  Restrooms
# 6           gtr        1         Vending machines     Retail
# 7           chs        1               Amazon One     Retail
# 8           fsd        1                Gift Shop     Retail
# 9           fsd        1                Gift Shop     Retail
# 10          lax        3           Hudson Nonstop     Retail
# 11          gtr        1         Vending machines     Retail
# 12          gtr        1         Vending machines     Retail
# 13          abq        1               Misc Shops     Retail
#
#                            location
# 0   Terminal 1 Level 1 near Gate 15
# 1                       Third Floor
# 2                            Gate 2
# 3              Level 2 near Gates B
# 4                       Near Gate 6
# 5                       Near Gate 2
# 6                     Gates B3 & B4
# 7                      Near gate A1
# 8                      Near Gate 15
# 9                       Near Gate 5
# 10                         Gate 37B
# 11                          Gate B2
# 12                          Gate B1
# 13                          Gate A2

# %% [markdown]
# #### Process entire table and save results to BQ

# %%
import json
import pandas_gbq
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import bigquery

prompt = """Go through the list of categories and look for categories that have similar meanings and have differences in spelling and naming.
For example, 'Airline Ticket Counters' and 'Airline Ticketing' have similar meanings and 'Mother Room and 'Mother's Room' have similar meanings.
Suggest a standard category, mapping the current one to the new one.
Return the list of original categories along with their new categories.
Format the results as a json object with the schema: current_category:string, new_category:string.
Do not include any unchanged categories with your answer.
Do not include an explanation with your answer.
"""
category_sql = "select distinct category from air_travel_raw.airport_businesses"

airport_businesses_sql = "select * from air_travel_raw.airport_businesses"

bq_client = bigquery.Client()
rows = bq_client.query_and_wait(category_sql)

category_list = []
for row in rows:
    category_list.append(row["category"])
category_str = '\n'.join(category_list)
#print("category_str:", category_str)

vertexai.init(project=project_id, location=region)
model = GenerativeModel(model_name)
resp = model.generate_content([category_str, prompt])
resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
print(resp_text)
categories = json.loads(resp_text)
print(type(categories))

replacements = {} # will store the new categories

# categories may be returned either as dictionary or list, depending on what LLM decides to do!
if type(categories) == dict:
    for old, new in categories.items():
        if old == new:
            continue
        else:
            replacements[old] = new

if type(categories) == list:
    for cat_entry in categories:
        if cat_entry['current_category'] == cat_entry['new_category']:
            continue
        else:
            replacements[cat_entry['current_category']] = cat_entry['new_category']

print("replacements:", replacements)

# read the table and merge in the changes
df = bq_client.query_and_wait(airport_businesses_sql).to_dataframe()
print("orig df:", df)

df["category"] = df["category"].map(replacements).fillna(df["category"])
print("new df:", df)

table_id = "air_travel_stg.tmp_airport_businesses"
pandas_gbq.to_gbq(df, table_id, project_id=project_id, if_exists="replace")
# Out:
# [    {        "current_category": "Baggage Service",        "new_category": "Baggage Handling"    },    {        "current_category": "Duty Free Shop",        "new_category": "Duty Free"    },    {        "current_category": "Restrooms",        "new_category": "Restroom"    },   {        "current_category": "Airline Ticket Counters",        "new_category": "Airline Ticketing"    },  {        "current_category": "Food/Drink",         "new_category": "Food & Drink"    },   {        "current_category": "Sporting Goods Store",        "new_category": "Sporting Goods"    },  {        "current_category": "Newsagent",        "new_category": "Newsstand"    },  {        "current_category": "Newsstand/Coffee Shop",        "new_category": "Newsstand"    },    {        "current_category": "Cosmetics Store",        "new_category": "Cosmetics"    },    {      "current_category": "Shipping",      "new_category": "Shipping Company"     },    {        "current_category": "Airport Security",        "new_category": "Security"    },    {       "current_category": "News Kiosk",       "new_category":"Newsstand"     },  {        "current_category": "Gift shop",        "new_category": "Gift Shop"    },  {       "current_category": "News Stand",       "new_category": "Newsstand"     },    {       "current_category": "Pretzel Shop",       "new_category": "Pretzels"     },   {        "current_category": "Airline Club & Lounges",        "new_category": "Lounge"    },  {        "current_category": "Dinning",        "new_category":"Dining"    },   {       "current_category":"Air Service",       "new_category":"Airline Services"    },    {       "current_category": "Convenience store",       "new_category":"Convenience Store"    },    {        "current_category": "Cafe",        "new_category": "Coffee Shop"    },    {        "current_category":"airline",        "new_category":"Airline"     },    {        "current_category":"shopping",         "new_category":"Shopping"     },  {        "current_category":"car rental",         "new_category":"Car Rental"    },    {        "current_category":"Airport Service",        "new_category":"Airport Services"    },   {        "current_category": "airport services",        "new_category": "Airport Services"    },    {        "current_category": "Coffee shop",        "new_category": "Coffee Shop"    },    {        "current_category": "airline cargo",        "new_category": "Cargo Services"   },    {        "current_category": "Restaurant",        "new_category":"Restaurant"     },    {      "current_category": "Things to do",      "new_category": "Things To Do"    }]
# <class 'list'>
# replacements: {'Baggage Service': 'Baggage Handling', 'Duty Free Shop': 'Duty Free', 'Restrooms': 'Restroom', 'Airline Ticket Counters': 'Airline Ticketing', 'Food/Drink': 'Food & Drink', 'Sporting Goods Store': 'Sporting Goods', 'Newsagent': 'Newsstand', 'Newsstand/Coffee Shop': 'Newsstand', 'Cosmetics Store': 'Cosmetics', 'Shipping': 'Shipping Company', 'Airport Security': 'Security', 'News Kiosk': 'Newsstand', 'Gift shop': 'Gift Shop', 'News Stand': 'Newsstand', 'Pretzel Shop': 'Pretzels', 'Airline Club & Lounges': 'Lounge', 'Dinning': 'Dining', 'Air Service': 'Airline Services', 'Convenience store': 'Convenience Store', 'Cafe': 'Coffee Shop', 'airline': 'Airline', 'shopping': 'Shopping', 'car rental': 'Car Rental', 'Airport Service': 'Airport Services', 'airport services': 'Airport Services', 'Coffee shop': 'Coffee Shop', 'airline cargo': 'Cargo Services', 'Things to do': 'Things To Do'}
# orig df:      airport_code terminal                      business            category  \
# 0             pgd        1                           ATM  Financial Services
# 1             ege        1  Delta Baggage Service Office     Baggage Service
# 2             cwa        1               Wending Machine              Snacks
# 3             gtr        2    Airport Management Offices          Management
# 4             oak        1       Duty Free World Passage      Duty Free Shop
# ...           ...      ...                           ...                 ...
# 1569          hou        1                    Brookstone   Electronics Store
# 1570          pwm        1              Best Buy Express   Electronics Store
# 1571          lax        6                        Belkin   Electronics Store
# 1572          las        1                    Brookstone   Electronics Store
# 1573          syr        1                        eSavvy   Electronics Store
#
#                              location menu_items  _data_source  \
# 0                              Gate 1       None  airportguide
# 1                              Gate 1       None  airportguide
# 2                              Gate 2       None  airportguide
# 3                              Gate 2       None  airportguide
# 4                              Gate 2       None  airportguide
# ...                               ...        ...           ...
# 1569                        Gates 1-4       None  airportguide
# 1570                     Near Gate 11       None  airportguide
# 1571                     Near gate 60       None  airportguide
# 1572               Terminal 1 Level 1       None  airportguide
# 1573  Terminal 1 Level 2 near Gate 10       None  airportguide
#
#                            _load_time
# 0    2025-01-24 18:51:53.320638+00:00
# 1    2025-01-24 18:51:53.320638+00:00
# 2    2025-01-24 18:51:53.320638+00:00
# 3    2025-01-24 18:51:53.320638+00:00
# 4    2025-01-24 18:51:53.320638+00:00
# ...                               ...
# 1569 2025-01-24 18:51:53.320638+00:00
# 1570 2025-01-24 18:51:53.320638+00:00
# 1571 2025-01-24 18:51:53.320638+00:00
# 1572 2025-01-24 18:51:53.320638+00:00
# 1573 2025-01-24 18:51:53.320638+00:00
#
# [1574 rows x 8 columns]
# new df:      airport_code terminal                      business            category  \
# 0             pgd        1                           ATM  Financial Services
# 1             ege        1  Delta Baggage Service Office    Baggage Handling
# 2             cwa        1               Wending Machine              Snacks
# 3             gtr        2    Airport Management Offices          Management
# 4             oak        1       Duty Free World Passage           Duty Free
# ...           ...      ...                           ...                 ...
# 1569          hou        1                    Brookstone   Electronics Store
# 1570          pwm        1              Best Buy Express   Electronics Store
# 1571          lax        6                        Belkin   Electronics Store
# 1572          las        1                    Brookstone   Electronics Store
# 1573          syr        1                        eSavvy   Electronics Store
#
#                              location menu_items  _data_source  \
# 0                              Gate 1       None  airportguide
# 1                              Gate 1       None  airportguide
# 2                              Gate 2       None  airportguide
# 3                              Gate 2       None  airportguide
# 4                              Gate 2       None  airportguide
# ...                               ...        ...           ...
# 1569                        Gates 1-4       None  airportguide
# 1570                     Near Gate 11       None  airportguide
# 1571                     Near gate 60       None  airportguide
# 1572               Terminal 1 Level 1       None  airportguide
# 1573  Terminal 1 Level 2 near Gate 10       None  airportguide
#
#                            _load_time
# 0    2025-01-24 18:51:53.320638+00:00
# 1    2025-01-24 18:51:53.320638+00:00
# 2    2025-01-24 18:51:53.320638+00:00
# 3    2025-01-24 18:51:53.320638+00:00
# 4    2025-01-24 18:51:53.320638+00:00
# ...                               ...
# 1569 2025-01-24 18:51:53.320638+00:00
# 1570 2025-01-24 18:51:53.320638+00:00
# 1571 2025-01-24 18:51:53.320638+00:00
# 1572 2025-01-24 18:51:53.320638+00:00
# 1573 2025-01-24 18:51:53.320638+00:00
#
# [1574 rows x 8 columns]
# 100%|██████████| 1/1 [00:00<00:00, 6114.15it/s]

# %% [markdown]
# #### Check the output table

# %%
# %%bigquery
# select distinct category from air_travel_stg.tmp_airport_businesses order by category
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                category
# 0                   ATM
# 1        Administration
# 2    Air Transportation
# 3               Airline
# 4        Airline Office
# ..                  ...
# 157              police
# 158          restaurant
# 159            security
# 160    shipping company
# 161      transportation
#
# [162 rows x 1 columns]

# %% [markdown]
# #### Now do the same thing with the business names, i.e. standardize them to reduce inconsistencies

# %%
import json
import pandas_gbq
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import bigquery

prompt = """Go through this list of business names and standardize them to remove the variations in spelling.
For example, 'Sweet Jill Bakery' and 'Sweet Jill's Bakery' both refer to the same business, so standardize on one or the other.
Another example is, 'Alaska Airline' and 'Alaska Airlines'. Since they both refer to the same business, standardize on 'Alaska Airlines'.
Suggest a standard name, mapping the current one to the new one.
Return the list of original business names along with their new names.
Format the results as a json object with the schema: current_name:string, new_new:string.
Do not include any unchanged business names with your answer.
Do not include an explanation with your answer.
"""
business_names_sql = "select distinct business from air_travel_stg.tmp_airport_businesses order by business"

airport_businesses_sql = "select * from air_travel_stg.tmp_airport_businesses"


def do_inference(input_str):

    vertexai.init(project=project_id, location=region)
    model = GenerativeModel(model_name)
    resp = model.generate_content([input_str, prompt])
    resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
    print(resp_text)

    names = json.loads(resp_text)
    print(type(names))

    replacements = {}

    # names can be returned as either a dictionary or list type, depending on what the LLM decides to do!
    if type(names) == dict:
        for old, new in names.items():
            if old == new:
                continue
            else:
                replacements[old] = new

    if type(names) == list:
        for name_entry in names:
            if 'current_name' not in cat_entry or 'new_name' not in cat_entry:
              continue

            if name_entry['current_name'] == name_entry['new_name']:
                continue

            replacements[cat_entry['current_name']] = cat_entry['new_name']

    return replacements


bq_client = bigquery.Client()
rows = bq_client.query_and_wait(business_names_sql)

batch_size = 500
business_names = []
combined_replacements = {}

for i, row in enumerate(rows):

    business_names.append(row["business"])

    if i > 0 and i % batch_size == 0:
        # process batch
        print("processing batch")
        business_names_str = '\n'.join(business_names)
        replacements = do_inference(business_names_str)
        combined_replacements.update(replacements)

        # reset business_names to process next batch
        business_names = []

if len(business_names) > 0:
    print("processing last batch")
    business_names_str = '\n'.join(business_names)
    replacements = do_inference(business_names_str)
    combined_replacements.update(replacements)

print("replacements:", replacements)

# read the table and merge in the changes
df = bq_client.query_and_wait(airport_businesses_sql).to_dataframe()
print("orig df:", df)

df["business"] = df["business"].map(replacements).fillna(df["business"])
print("new df:", df)

table_id = "air_travel_stg.airport_businesses" # output table
pandas_gbq.to_gbq(df, table_id, project_id=project_id, if_exists="replace")
# Out:
# processing batch
# [    {        "current_name": "13th Street Pub and Grill",        "new_name": "13th Street Pub & Grill"    },    {        "current_name": "8oz. Burger Bar",        "new_name": "8oz Burger Bar"     },    {        "current_name": "Air Canada Airlines",        "new_name": "Air Canada"    },    {         "current_name": "Airline Ticketing Lobbe",        "new_name": "Airline Ticketing Lobby"    },     {        "current_name": "Alamo Rent A Car",        "new_name": "Alamo Car Rental"    },    {        "current_name": "Alamo Rental Car",        "new_name": "Alamo Car Rental"    },   {        "current_name": "Alaska Airline",        "new_name": "Alaska Airlines"    },   {        "current_name": "Alaska Airlines Bag Claim Office",        "new_name": "Alaska Airlines Baggage Claim Office"    },    {        "current_name":"Alaska Airlines Ticketing",        "new_name":"Alaska Airlines Ticketing"     },   {        "current_name": "Allegiant Air",        "new_name": "Allegiant Airlines"    },  {        "current_name": "Allegiant Airline",        "new_name": "Allegiant Airlines"    },    {       "current_name": "American Air",       "new_name":"American Airlines"    },    {      "current_name": "American Air Lines",      "new_name": "American Airlines"    },    {      "current_name":"American Airline",      "new_name":"American Airlines"    },    {        "current_name": "American Airlines Bag Claim Office",        "new_name": "American Airlines Baggage Claim Office"    },    {        "current_name": "American Airlines Inc",         "new_name": "American Airlines"    },    {        "current_name": "American Airlines Ticketing",        "new_name": "American Airlines Ticketing"    },    {         "current_name": "American Baggage Office",         "new_name": "American Airlines Baggage Office"     },    {         "current_name": "American Baggage Service Office",         "new_name":"American Airlines Baggage Service Office"     },    {      "current_name": "Applebee's Grill + Bar",      "new_name":"Applebee's Grill & Bar"    },   {        "current_name":"Avis Airlines",        "new_name":"Avis Car Rental"    },    {        "current_name": "Bar & Gril",        "new_name": "Bar & Grill"    },     {         "current_name":"Beverages and food",         "new_name":"Beverages & Food"     },     {       "current_name":"Beverages and food & Gift",       "new_name":"Beverages, Food & Gift"     },   {        "current_name":"Beverages and food & Gift & News",        "new_name":"Beverages, Food, Gift & News"    },    {        "current_name":"Breeze Air",        "new_name":"Breeze Airways"    },    {      "current_name": "Breeze Airline",      "new_name": "Breeze Airways"    },    {      "current_name": "Business center",      "new_name": "Business Center"    },     {        "current_name": "Bussines Center",        "new_name":"Business Center"     },    {       "current_name":"Cafe Peet's Coffee",       "new_name":"Peet's Coffee"    },    {      "current_name":"Car Rental National",      "new_name":"National Car Rental"    },    {        "current_name":"Caribou Coffee/Cinnabon",        "new_name":"Caribou Coffee & Cinnabon"    },   {        "current_name":"Chili's Grill and Bar",        "new_name":"Chili's Grill & Bar"    },    {        "current_name":"Coffee Bean & Tea Leaf",        "new_name":"Coffee Bean and Tea Leaf"     },    {        "current_name": "Computer/Charging Station",        "new_name":"Computer & Charging Station"    },    {        "current_name":"Convenience Store Entertainment News",        "new_name":"Convenience Store & Entertainment News"    },    {       "current_name":"Cross Grains On The Go",       "new_name":"Cross Grain On The Go"     },    {       "current_name":"Delta Air",       "new_name":"Delta Airlines"     },    {         "current_name":"Delta Air Lines",         "new_name":"Delta Airlines"     },   {        "current_name":"Delta Airline",        "new_name":"Delta Airlines"     },   {        "current_name": "Delta Airline ...
# <class 'list'>
# processing batch
# [    {        "current_name": "Jamba",        "new_name": "Jamba Juice"    },    {      "current_name": "Jersey Mike's",      "new_name": "Jersey Mike's Subs"    },   {        "current_name": "Jet Set Express",        "new_name": "JetSet Express"    },    {        "current_name": "JetBlue Air",        "new_name": "JetBlue Airlines"    },        {        "current_name": "JetBlue",         "new_name": "JetBlue Airlines"    },     {        "current_name": "JetBlue Airlines Bag Claim Office",         "new_name": "JetBlue Airlines Baggage Claim Office"    },    {        "current_name": "JetBox Market",        "new_name": "Jetbox Market"    },    {       "current_name": "Kids Zone",       "new_name":"KidZone"    },    {        "current_name":"Kids' Spot",        "new_name":"KidZone"    },    {        "current_name": "Kylie Skin Cosmetics",       "new_name": "Kylie Cosmetics"    },    {      "current_name": "L.A. Times Newsstand",      "new_name": "LA Times Newsstand"     },    {       "current_name":"LAMILL Coffee",       "new_name":"La Mill Coffee"    },      {      "current_name":"Little Free Library",      "new_name":"Little Free Libraries"    },    {        "current_name": "Long Beach News",        "new_name": "Long Beach Newsstand"    },    {        "current_name":"MAC Cosmetics",         "new_name":"MAC"    },   {      "current_name":"M. Fredric",       "new_name": "M.Fredric"   },    {        "current_name":"Meeting Room A",        "new_name":"Meeting Room"    },     {        "current_name":"Meeting Room B",        "new_name":"Meeting Room"    },   {        "current_name":"Mokulele Air",         "new_name":"Mokulele Airlines"    },   {        "current_name":"Mother's Room",         "new_name":"Mother Room"    },    {     "current_name":"NYS Eyewear",     "new_name":"NYS"     },     {     "current_name":"News Stand/Gifts",     "new_name": "News Stand"    },    {      "current_name":"Nursing room",      "new_name":"Nursing Room"     },   {       "current_name":"Paradies Avanti Marcet",        "new_name":"Paradies Shops"   },    {      "current_name":"Paradies Shop",      "new_name":"Paradies Shops"    },     {       "current_name": "Papa Gino's",       "new_name": "Papa Gino's Restaurant"     },     {         "current_name":"Pappa's Bar-B-Q",         "new_name": "Pappa's BBQ"     },     {      "current_name":"Pappa's Burger",      "new_name":"Pappa's Burgers"     },     {        "current_name":"Peet's Coffee & Tea",        "new_name":"Peet's Coffee"    },    {        "current_name": "Phillips Seafood Restaurant",        "new_name": "Phillips Seafood"    },    {      "current_name":"Pizza Hut Express",       "new_name":"Pizza Hut"    },     {        "current_name": "Plane Box",        "new_name":"Plane Box Market"    },     {         "current_name":"Polly's Coffee",         "new_name":"Polly's Coffee Shop"     },    {        "current_name":"PopSox",        "new_name":"PopSox Shop"    },    {        "current_name":"Post-Security",        "new_name":"Post Security"    },    {       "current_name":"PrairieBistro and Java Creek Cafe",       "new_name":"PrairieBistro Cafe"     },    {       "current_name":"Restaurant",        "new_name":"Restaurant Dining"     },    {      "current_name":"Restaurant Post-Security",      "new_name":"Restaurant Dining Post Security"    },    {        "current_name": "Restaurant Pre-Security",        "new_name": "Restaurant Dining Pre Security"    },    {      "current_name":"Restaurant Pyramid Ale Taproom",      "new_name":"Pyramid Ale Taproom"    },    {      "current_name":"Restaurant-Bar",      "new_name": "Restaurant Bar"    },   {      "current_name":"Rocky Mountain Chocolate Factory",      "new_name":"Rocky Mountain Chocolate"    },   {      "current_name":"Route 66 News and Gifts",      "new_name":"Route 66 Newsstand"    },    {        "current_name":"SF Uncork'd",         "new_name":"SF Uncorked"    },    {       "current_name":"SCOTTY BROWNS BLI",       "new_name":"Scotty Browns"    },    {    ...
# <class 'list'>
# processing last batch
# [    {        "current_name": "United Baggage Office",        "new_name": "United Baggage Services"    },    {        "current_name": "United Baggage Service Office",         "new_name": "United Baggage Services"    },     {        "current_name": "Vending Mechine",        "new_name": "Vending Machine"    },    {        "current_name":"Vending machine",         "new_name": "Vending Machine"    },      {        "current_name":"Vending machines",         "new_name": "Vending Machine"    },    {       "current_name": "Wending Machine",       "new_name": "Vending Machine"    },     {        "current_name": "XpresSpa",        "new_name": "Xpress Spa"    },    {        "current_name": "jetBlue Airlines Ticketing",         "new_name":"jetBlue"    },      {        "current_name": "iStore Boutique",         "new_name":"iStore"    }]
# <class 'list'>
# replacements: {}
# orig df:      airport_code terminal                      business            category  \
# 0             pgd        1                           ATM  Financial Services
# 1             ege        1  Delta Baggage Service Office    Baggage Handling
# 2             cwa        1               Wending Machine              Snacks
# 3             gtr        2    Airport Management Offices          Management
# 4             oak        1       Duty Free World Passage           Duty Free
# ...           ...      ...                           ...                 ...
# 1569          hou        1                    Brookstone   Electronics Store
# 1570          pwm        1              Best Buy Express   Electronics Store
# 1571          lax        6                        Belkin   Electronics Store
# 1572          las        1                    Brookstone   Electronics Store
# 1573          syr        1                        eSavvy   Electronics Store
#
#                              location menu_items  _data_source  \
# 0                              Gate 1       None  airportguide
# 1                              Gate 1       None  airportguide
# 2                              Gate 2       None  airportguide
# 3                              Gate 2       None  airportguide
# 4                              Gate 2       None  airportguide
# ...                               ...        ...           ...
# 1569                        Gates 1-4       None  airportguide
# 1570                     Near Gate 11       None  airportguide
# 1571                     Near gate 60       None  airportguide
# 1572               Terminal 1 Level 1       None  airportguide
# 1573  Terminal 1 Level 2 near Gate 10       None  airportguide
#
#                            _load_time
# 0    2025-01-24 18:51:53.320638+00:00
# 1    2025-01-24 18:51:53.320638+00:00
# 2    2025-01-24 18:51:53.320638+00:00
# 3    2025-01-24 18:51:53.320638+00:00
# 4    2025-01-24 18:51:53.320638+00:00
# ...                               ...
# 1569 2025-01-24 18:51:53.320638+00:00
# 1570 2025-01-24 18:51:53.320638+00:00
# 1571 2025-01-24 18:51:53.320638+00:00
# 1572 2025-01-24 18:51:53.320638+00:00
# 1573 2025-01-24 18:51:53.320638+00:00
#
# [1574 rows x 8 columns]
# new df:      airport_code terminal                      business            category  \
# 0             pgd        1                           ATM  Financial Services
# 1             ege        1  Delta Baggage Service Office    Baggage Handling
# 2             cwa        1               Wending Machine              Snacks
# 3             gtr        2    Airport Management Offices          Management
# 4             oak        1       Duty Free World Passage           Duty Free
# ...           ...      ...                           ...                 ...
# 1569          hou        1                    Brookstone   Electronics Store
# 1570          pwm        1              Best Buy Express   Electronics Store
# 1571          lax        6                        Belkin   Electronics Store
# 1572          las        1                    Brookstone   Electronics Store
# 1573          syr        1                        eSavvy   Electronics Store
#
#                              location menu_items  _data_source  \
# 0                              Gate 1       None  airportguide
# 1                              Gate 1       None  airportguide
# 2                              Gate 2       None  airportguide
# 3                              Gate 2       None  airportguide
# 4                              Gate 2       None  airportguide
# ...                               ...        ...           ...
# 1569                        Gates 1-4       None  airportguide
# 1570                     Near Gate 11       None  airportguide
# 1571                     Near gate 60       None  airportguide
# 1572               Terminal 1 Level 1       None  airportguide
# 1573  Terminal 1 Level 2 near Gate 10       None  airportguide
#
#                            _load_time
# 0    2025-01-24 18:51:53.320638+00:00
# 1    2025-01-24 18:51:53.320638+00:00
# 2    2025-01-24 18:51:53.320638+00:00
# 3    2025-01-24 18:51:53.320638+00:00
# 4    2025-01-24 18:51:53.320638+00:00
# ...                               ...
# 1569 2025-01-24 18:51:53.320638+00:00
# 1570 2025-01-24 18:51:53.320638+00:00
# 1571 2025-01-24 18:51:53.320638+00:00
# 1572 2025-01-24 18:51:53.320638+00:00
# 1573 2025-01-24 18:51:53.320638+00:00
#
# [1574 rows x 8 columns]
# 100%|██████████| 1/1 [00:00<00:00, 6543.38it/s]

# %%
# %%bigquery
# select * from air_travel_stg.airport_businesses
# order by business desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      airport_code terminal                    business      category  \
# 0             sba        1              “SB Sky Gazing  Things To Do
# 1             sba        1            “Good Time Clock  Things To Do
# 2             sba        1                     “Fiesta  Things To Do
# 3             abq        1  jetBlue Airlines Ticketing     Ticketing
# 4             hdn        1                     jetBlue       Airline
# ...           ...      ...                         ...           ...
# 1569          lgb        1                    4th Vine    Restaurant
# 1570          sfo        2              49 Mile Market      Shopping
# 1571          pie        1  3 Daughters Brewing at PIE        Dining
# 1572          boi        1   13th Street Pub and Grill        Dining
# 1573          psp        1    12th Fairway Bar & Grill    Restaurant
#
#                       location                             menu_items  \
# 0                Near gates G3                                   None
# 1     Near Car Rental National                                   None
# 2                Near gates G3                                   None
# 3                 Second Floor                                   None
# 4                      Gate 13                                   None
# ...                        ...                                    ...
# 1569             Near Gates G2    Wine,Cheese Plate,Charcuterie Board
# 1570               Concourse D                                   None
# 1571                    Gate 2                     IPA,Stout,Pale Ale
# 1572    Near gates B15 and B17  Pub Burger,Fish & Chips,Chicken Wings
# 1573                   Gate 11              Sandwiches,Salads,Burgers
#
#       _data_source                       _load_time
# 0     airportguide 2025-01-24 18:51:53.320638+00:00
# 1     airportguide 2025-01-24 18:51:53.320638+00:00
# 2     airportguide 2025-01-24 18:51:53.320638+00:00
# 3     airportguide 2025-01-24 18:51:53.320638+00:00
# 4     airportguide 2025-01-24 18:51:53.320638+00:00
# ...            ...                              ...
# 1569  airportguide 2025-01-24 18:51:53.320638+00:00
# 1570  airportguide 2025-01-24 18:51:53.320638+00:00
# 1571  airportguide 2025-01-24 18:51:53.320638+00:00
# 1572  airportguide 2025-01-24 18:51:53.320638+00:00
# 1573  airportguide 2025-01-24 18:51:53.320638+00:00
#
# [1574 rows x 8 columns]

# %% [markdown]
# #### Look for certain unwanted characters in the business name

# %%
# %%bigquery
# select * from air_travel_stg.airport_businesses
# where business like '“%'
# order by business
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   airport_code terminal          business      category  \
# 0          sba        1           “Fiesta  Things To Do
# 1          sba        1  “Good Time Clock  Things To Do
# 2          sba        1    “SB Sky Gazing  Things To Do
#
#                    location menu_items  _data_source  \
# 0             Near gates G3       None  airportguide
# 1  Near Car Rental National       None  airportguide
# 2             Near gates G3       None  airportguide
#
#                         _load_time
# 0 2025-01-24 18:51:53.320638+00:00
# 1 2025-01-24 18:51:53.320638+00:00
# 2 2025-01-24 18:51:53.320638+00:00

# %% [markdown]
# #### Create staging table and remove unwanted characters

# %%
# %%bigquery
# create or replace table air_travel_stg.airport_businesses as
#     select airport_code, terminal, replace(business, '“', '') as business,
#       category, location, menu_items, _data_source, _load_time
#     from air_travel_stg.airport_businesses
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from air_travel_stg.airport_businesses
# where business like '“%'
# order by business
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [airport_code, terminal, business, category, location, menu_items, _data_source, _load_time]
# Index: []

# %% [markdown]
# #### Cleanup

# %%
# %%bigquery
# drop table air_travel_stg.tmp_airport_businesses
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airport_reviews` table

# %% [markdown]
# #### Rename fields and create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.airport_reviews as
# 	select id,
# 	threadRef as thread_id,
# 	airportRef as airport_id,
# 	airportIdent as airport_code,
# 	date as date_created,
# 	memberNickname as author,
# 	subject,
# 	body,
# 	_data_source,
# 	_load_time
# 	from air_travel_raw.airport_reviews
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `airports` table

# %% [markdown]
# #### Profile `source` and `type` fields

# %%
# %%bigquery
# select count(*) source_count
# from air_travel_raw.airports
# where source != '\\N' and source is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    source_count
# 0         11017

# %%
# %%bigquery
# select count(*) type_count
# from air_travel_raw.airports
# where type != '\\N' and type is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    type_count
# 0       11017

# %%
# %%bigquery
# select distinct source
# from air_travel_raw.airports
# where source != '\\N' and source is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         source
# 0         User
# 1       Legacy
# 2  OurAirports

# %%
# %%bigquery
# select distinct type
# from air_travel_raw.airports
# where type != '\\N' and type is not null
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#       type
# 0  unknown
# 1  airport
# 2  station
# 3     port

# %%
# %%bigquery
# 	select safe_cast(airport_id as INTEGER) as airport_id,
# 	airport_name,
# 	city,
# 	country,
# 	case iata
# 		when '\\N' then null
# 		else iata
# 		end as iata,
# 	case icao
# 		when '\\N' then null
# 		else icao
# 		end as icao,
# 	latitude,
# 	longitude,
# 	altitude,
# 	safe_cast(timezone as INTEGER) as timezone_delta,
#   daylight_savings_time,
#   case tz_database_timezone
# 		when '\\N' then null
# 		else tz_database_timezone
# 		end as timezone_name,
# 	case type
# 		when '\\N' then null
# 		else type
# 		end as type,
# 	case source
# 		when '\\N' then null
# 		else source
# 		end as source,
# 	_data_source
# 	_load_time
# 	from air_travel_raw.airports
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        airport_id                 airport_name                 city  \
# 0           11746                    Kona Dock   Kailua-Kona Hawaii
# 1           12060             Kanuhuraa Island     Kanuhuraa Island
# 2           12061               Kwara Airstrip           Kwara Camp
# 3           12062                Matemo Island        Matemo Island
# 4           12063              Medjumbe Island      Medjumbe Island
# ...           ...                          ...                  ...
# 12663        2500           Santa Cruz Airport           Santa Cruz
# 12664        4061          El Calafate Airport          El Calafate
# 12665        6028            Las Heras Airport            Las Heras
# 12666        6030       Lago Argentino Airport          El Calafate
# 12667        6031  Gobernador Gregores Airport  Gobernador Gregores
#
#              country  iata  icao                                    latitude  \
# 0      United States  None  None   19.63858700000000000000000000000000000000
# 1           Maldives  None  None    5.53413100000000000000000000000000000000
# 2           Botswana  None  None  -19.10142900000000000000000000000000000000
# 3         Mozambique  None  None  -12.20077300000000000000000000000000000000
# 4         Mozambique  None  None  -11.81743200000000000000000000000000000000
# ...              ...   ...   ...                                         ...
# 12663      Argentina   RZA  SAWU  -50.01650000000000000000000000000000000000
# 12664      Argentina   FTE  SAWC  -50.28030000000000000000000000000000000000
# 12665      Argentina   LHS  SAVH  -46.53829956049999000000000000000000000000
# 12666      Argentina   ING  SAWA  -50.33610200000000000000000000000000000000
# 12667      Argentina   GGS  SAWR  -48.78310000000000000000000000000000000000
#
#                                          longitude  altitude  timezone_delta  \
# 0      -155.99673900000000000000000000000000000000         0             -10
# 1        73.50598100000000000000000000000000000000         0               5
# 2        23.28379800000000000000000000000000000000         0               1
# 3        40.56896900000000000000000000000000000000         0               1
# 4        40.60365600000000000000000000000000000000         0               1
# ...                                            ...       ...             ...
# 12663   -68.57920000000000000000000000000000000000       364              -3
# 12664   -72.05310100000000000000000000000000000000       669              -3
# 12665   -68.96530151370000000000000000000000000000      1082              -3
# 12666   -72.24859600000000000000000000000000000000       732              -3
# 12667   -70.15000200000000000000000000000000000000       356              -3
#
#       daylight_savings_time                   timezone_name     type  \
# 0                         A                            None     None
# 1                         N                            None     None
# 2                         U                            None     None
# 3                         U                            None     None
# 4                         U                            None     None
# ...                     ...                             ...      ...
# 12663                     N  America/Argentina/Rio_Gallegos  airport
# 12664                     N  America/Argentina/Rio_Gallegos  airport
# 12665                     N  America/Argentina/Rio_Gallegos  airport
# 12666                     N  America/Argentina/Rio_Gallegos  airport
# 12667                     N  America/Argentina/Rio_Gallegos  airport
#
#             source   _load_time
# 0             None  openflights
# 1             None  openflights
# 2             None  openflights
# 3             None  openflights
# 4             None  openflights
# ...            ...          ...
# 12663  OurAirports  openflights
# 12664  OurAirports  openflights
# 12665  OurAirports  openflights
# 12666  OurAirports  openflights
# 12667  OurAirports  openflights
#
# [12668 rows x 15 columns]

# %%
# %%bigquery
# select count(*) as type_not_null
# from air_travel_raw.airports
# where type is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    type_not_null
# 0          12668

# %%
# %%bigquery
# select count(*) as source_not_null
# from air_travel_raw.airports
# where source is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    source_not_null
# 0            12668

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.airports as
# 	select safe_cast(airport_id as INTEGER) as airport_id,
# 	airport_name,
# 	city,
# 	country,
# 	case iata
# 		when '\\N' then null
# 		else iata
# 		end as iata,
# 	case icao
# 		when '\\N' then null
# 		else icao
# 		end as icao,
# 	latitude,
# 	longitude,
# 	altitude,
# 	safe_cast(timezone as INTEGER) as timezone_delta,
#   daylight_savings_time,
#   case tz_database_timezone
# 		when '\\N' then null
# 		else tz_database_timezone
# 		end as timezone_name,
# 	case type
# 		when '\\N' then null
# 		else type
# 		end as type,
# 	case source
# 		when '\\N' then null
# 		else source
# 		end as source,
# 	_data_source,
# 	_load_time
# 	from air_travel_raw.airports
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `countries` table

# %% [markdown]
# ##### Profile `country_name`, `iso_code`, and `dafif_code`

# %%
# %%bigquery
# select count(*) as empty_country_name
# from air_travel_raw.countries
# where country_name = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_country_name
# 0                   0

# %%
# %%bigquery
# select count(*) as empty_iso_code
# from air_travel_raw.countries
# where iso_code = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_iso_code
# 0              19

# %%
# %%bigquery
# select count(*) as empty_dafif_code
# from air_travel_raw.countries
# where dafif_code = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_dafif_code
# 0                 0

# %% [markdown]
# #### Replace `'\\N'` with null

# %%
# %%bigquery
# select country_name as name,
# case iso_code
#   when '\\N' then null
#   else iso_code
#   end as iso_code,
# dafif_code
# from air_travel_raw.countries
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                      name iso_code dafif_code
# 0    United Arab Emirates       AE         AE
# 1             Afghanistan       AF         AF
# 2     Antigua and Barbuda       AG         AC
# 3                Anguilla       AI         AV
# 4                 Albania       AL         AL
# ..                    ...      ...        ...
# 256        Midway Islands     None         MQ
# 257       Paracel Islands     None         PF
# 258       Spratly Islands     None         PG
# 259       Tromelin Island     None         TE
# 260           Wake Island     None         WQ
#
# [261 rows x 3 columns]

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.countries as
#     select country_name as name,
#     case iso_code
#       when '\\N' then null
#       else iso_code
#       end as iso_code,
#     dafif_code,
#     _data_source,
#     _load_time
#     from air_travel_raw.countries
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `flight_delays` table

# %%
# %%bigquery
# select airport_name
# from air_travel_raw.flight_delays
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                         airport_name
# 0                   Albany, NY: Albany International
# 1  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 2  Birmingham, AL: Birmingham-Shuttlesworth Inter...
# 3           Burlington, VT: Burlington International
# 4         Buffalo, NY: Buffalo Niagara International

# %% [markdown]
# #### Split `airport_name` into three components: city, state, airport

# %%
# %%bigquery
# select split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport
# from air_travel_raw.flight_delays
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        city_state                                    airport
# 0      Albany, NY                       Albany International
# 1     Atlanta, GA   Hartsfield-Jackson Atlanta International
# 2  Birmingham, AL     Birmingham-Shuttlesworth International
# 3  Burlington, VT                   Burlington International
# 4     Buffalo, NY              Buffalo Niagara International

# %%
# %%bigquery
# select split(city_state, ',')[0] as city, split(city_state, ',')[1] as state, airport
# from
#   (select split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport
#   from air_travel_raw.flight_delays
#   limit 5)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          city state                                    airport
# 0      Albany    NY                       Albany International
# 1     Atlanta    GA   Hartsfield-Jackson Atlanta International
# 2  Birmingham    AL     Birmingham-Shuttlesworth International
# 3  Burlington    VT                   Burlington International
# 4     Buffalo    NY              Buffalo Niagara International

# %% [markdown]
# #### Putting it all together

# %%
# %%bigquery
# select event_month, carrier, carrier_name, airport_code,
#   split(city_state, ',')[0] as airport_city, split(city_state, ',')[1] as airport_state,
#   airport_name, * except (event_month, carrier, carrier_name, airport_code, airport_name, city_state)
# from
#   (select date(year, month, 01) as event_month, carrier, carrier_name, airport as airport_code,
#   split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport_name,
#   safe_cast(arr_flights as INTEGER) as arr_total, safe_cast(arr_cancelled as INTEGER) as arr_cancelled,
#   safe_cast(arr_diverted as INTEGER) as arr_diverted, safe_cast(arr_delay as INTEGER) as arr_delay_min,
#   safe_cast(weather_delay as INTEGER) as weather_delay_min, safe_cast(nas_delay as INTEGER) as nas_delay_min,
#   safe_cast(late_aircraft_delay as INTEGER) as late_aircraft_delay_min, _data_source, _load_time
#   from air_travel_raw.flight_delays
#   limit 5)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   event_month carrier       carrier_name airport_code airport_city  \
# 0  2024-04-01      9E  Endeavor Air Inc.          ALB       Albany
# 1  2024-04-01      9E  Endeavor Air Inc.          ATL      Atlanta
# 2  2024-04-01      9E  Endeavor Air Inc.          BHM   Birmingham
# 3  2024-04-01      9E  Endeavor Air Inc.          BTV   Burlington
# 4  2024-04-01      9E  Endeavor Air Inc.          BUF      Buffalo
#
#   airport_state                               airport_name  arr_total  \
# 0            NY                       Albany International        115
# 1            GA   Hartsfield-Jackson Atlanta International       2032
# 2            AL     Birmingham-Shuttlesworth International         95
# 3            VT                   Burlington International        142
# 4            NY              Buffalo Niagara International        193
#
#    arr_cancelled  arr_diverted  arr_delay_min  weather_delay_min  \
# 0              0             0            865                 41
# 1              3             1          16233               1528
# 2              1             0            898                 55
# 3              5             1           1546                  9
# 4              1             1            668                 60
#
#    nas_delay_min  late_aircraft_delay_min _data_source  \
# 0             88                      219    transtats
# 1           1745                     7223    transtats
# 2            130                      610    transtats
# 3            121                     1260    transtats
# 4            197                      184    transtats
#
#                         _load_time
# 0 2025-01-24 18:52:28.819379+00:00
# 1 2025-01-24 18:52:28.819379+00:00
# 2 2025-01-24 18:52:28.819379+00:00
# 3 2025-01-24 18:52:28.819379+00:00
# 4 2025-01-24 18:52:28.819379+00:00

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.flight_delays as
#     select event_month, carrier, carrier_name, airport_code,
#     split(city_state, ',')[0] as airport_city, split(city_state, ',')[1] as airport_state,
#     airport_name, * except (event_month, carrier, carrier_name, airport_code, airport_name, city_state)
#     from
#         (select date(year, month, 01) as event_month, carrier, carrier_name, airport as airport_code,
#           split(airport_name, ':')[0] as city_state, split(airport_name, ':')[1] as airport_name,
#           safe_cast(arr_flights as INTEGER) as arr_total, safe_cast(arr_cancelled as INTEGER) as arr_cancelled,
#           safe_cast(arr_diverted as INTEGER) as arr_diverted, safe_cast(arr_delay as INTEGER) as arr_delay_min,
#           safe_cast(weather_delay as INTEGER) as weather_delay_min, safe_cast(nas_delay as INTEGER) as nas_delay_min,
#           safe_cast(late_aircraft_delay as INTEGER) as late_aircraft_delay_min, _data_source, _load_time
#           from air_travel_raw.flight_delays)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `flight_routes` table

# %% [markdown]
# #### Profile `source_airport`, `source_airport_id`, `dest_airport`, `dest_airport_id`

# %%
# %%bigquery
# select count(*) as empty_source_airport
# from air_travel_raw.flight_routes
# where source_airport = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_source_airport
# 0                     0

# %%
# %%bigquery
# select count(*) as empty_source_airport_id
# from air_travel_raw.flight_routes
# where source_airport_id = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_source_airport_id
# 0                      220

# %%
# %%bigquery
# select count(*) as empty_dest_airport
# from air_travel_raw.flight_routes
# where dest_airport = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_dest_airport
# 0                   0

# %%
# %%bigquery
# select count(*) as empty_dest_airport_id
# from air_travel_raw.flight_routes
# where dest_airport_id = '\\N'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    empty_dest_airport_id
# 0                    221

# %% [markdown]
# #### Cast airline_id, replace `'\\N'` with null and rename airport fields

# %%
# %%bigquery
# select airline_code,
#   safe_cast(airline_id as INTEGER) as airline_id,
#   source_airport as source_airport_code,
#   case source_airport_id
#     when '\\N' then null
#     else safe_cast(source_airport_id as INTEGER)
#     end as source_airport_id,
#   dest_airport as dest_airport_code,
#   case dest_airport_id
#     when '\\N' then null
#     else safe_cast(dest_airport_id as INTEGER)
#     end as dest_airport_id,
#   codeshare,
#   stops,
#   equipment,
#   _data_source,
#   _load_time
# from air_travel_raw.flight_routes
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   airline_code  airline_id source_airport_code  source_airport_id  \
# 0           2B         410                 AER               2965
# 1           2B         410                 ASF               2966
# 2           2B         410                 ASF               2966
# 3           2B         410                 CEK               2968
# 4           2B         410                 CEK               2968
#
#   dest_airport_code  dest_airport_id  codeshare  stops equipment _data_source  \
# 0               KZN             2990       <NA>      0       CR2  openflights
# 1               KZN             2990       <NA>      0       CR2  openflights
# 2               MRV             2962       <NA>      0       CR2  openflights
# 3               KZN             2990       <NA>      0       CR2  openflights
# 4               OVB             4078       <NA>      0       CR2  openflights
#
#                         _load_time
# 0 2025-01-24 18:55:26.925088+00:00
# 1 2025-01-24 18:55:26.925088+00:00
# 2 2025-01-24 18:55:26.925088+00:00
# 3 2025-01-24 18:55:26.925088+00:00
# 4 2025-01-24 18:55:26.925088+00:00

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.flight_routes as
#   select airline_code,
#     safe_cast(airline_id as INTEGER) as airline_id,
#     source_airport,
#     case source_airport_id
#       when '\\N' then null
#       else safe_cast(source_airport_id as INTEGER)
#       end as source_airport_id,
#     dest_airport,
#     case dest_airport_id
#       when '\\N' then null
#       else safe_cast(dest_airport_id as INTEGER)
#       end as dest_airport_id,
#     codeshare,
#     stops,
#     equipment,
#     _data_source,
#     _load_time
#   from air_travel_raw.flight_routes
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### `tsa_traffic` table

# %% [markdown]
# #### Cast `date` from STRING to DATE

# %%
# %%bigquery
# select date as orig_date, safe_cast(date as DATE) as new_date
# from air_travel_raw.tsa_traffic
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orig_date new_date
# 0  8/17/2022      NaT
# 1   5/8/2024      NaT
# 2  3/27/2024      NaT
# 3  7/24/2024      NaT
# 4   6/7/2023      NaT

# %%
# %%bigquery
# select date as orig_date, safe_cast(date as DATE format 'MM/DD/YYYY') as new_date
# from air_travel_raw.tsa_traffic
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    orig_date    new_date
# 0  8/17/2022  2022-08-17
# 1   5/8/2024  2024-05-08
# 2  3/27/2024  2024-03-27
# 3  7/24/2024  2024-07-24
# 4   6/7/2023  2023-06-07

# %% [markdown]
# #### Putting it all together

# %%
# %%bigquery
# select safe_cast(date as DATE format 'MM/DD/YYYY') as event_date,
#   safe_cast(hour as INTEGER) as event_hour,
#   airport_code,
#   airport_name,
#   city as airport_city,
#   state as airport_state,
#   checkpoint as tsa_checkpoint,
#   total_count as passenger_count
# from air_travel_raw.tsa_traffic
# limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    event_date  event_hour airport_code            airport_name airport_city  \
# 0  2022-08-17          13          ADK  Adak Naval Air Station         Adak
# 1  2024-05-08          12          ADK                    Adak         Adak
# 2  2024-03-27          12          ADK                    Adak         Adak
# 3  2024-07-24          13          ADK                    Adak         Adak
# 4  2023-06-07          12          ADK  Adak Naval Air Station         Adak
#
#   airport_state tsa_checkpoint  passenger_count
# 0            AK    Checkpoint1               67
# 1            AK    Checkpoint1               23
# 2            AK    Checkpoint1                7
# 3            AK    Checkpoint1                1
# 4            AK    Checkpoint1                3

# %% [markdown]
# #### Create staging table

# %%
# %%bigquery
# create or replace table air_travel_stg.tsa_traffic as
#   select safe_cast(date as DATE format 'MM/DD/YYYY') as event_date,
#     safe_cast(hour as INTEGER) as event_hour,
#     airport_code,
#     airport_name,
#     city as airport_city,
#     state as airport_state,
#     checkpoint as tsa_checkpoint,
#     total_count as passenger_count,
#     _data_source,
#     _load_time
#   from air_travel_raw.tsa_traffic
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []
